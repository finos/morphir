# %% [markdown]
# # Sample Notebook
#
# This is a sample notebook for integration testing.

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
6 * 7
# Out:
# 42

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %% [raw]
# <html>
# <body>Raw content</body>
# </html>
